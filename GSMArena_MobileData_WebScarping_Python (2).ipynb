# %%
#importing Packages
import bs4 as bs
import urllib.request
import pandas as pd
import os
import urllib.parse
from fake_useragent import UserAgent
import requests
path=r"C:\Users\NANI\Desktop"
os.chdir(path)

# %%
source = urllib.request.urlopen('https://www.gsmarena.com/acer_dx650-9000.php').read()
soup = bs.BeautifulSoup(source,'html5lib')
container=soup.body.find_all('table')
name=soup.body.find_all('h1')
length_container=len(container)
print(length_container)
# Out:
# 14

# %%
for i in range(10):
    print(container[i].text.strip())
# Out:
# Network
# Technology
# GSM / CDMA / HSPA / EVDO / LTE
#
#
# 2G bands
# GSM 850 / 900 / 1800 / 1900 - SIM 1 & SIM 2 (dual-SIM model only)
#
#
# CDMA 800 / 1900 - USA
#
#
# 3G bands
# HSDPA 850 / 900 / 1900 / 2100 - Europe, Brazil
#
#
#
# HSDPA 850 / 900 / 1700(AWS) / 1900 / 2100 - USA
#
#
#
# CDMA2000 1xEV-DO - USA
#
#
#
# HSDPA 850 / 900 / 1900 / 2100 / 800 - India
#
#
# 4G bands
# LTE band 1(2100), 3(1800), 5(850), 7(2600), 8(900), 20(800), 38(2600) - Europe
#
#
#
# LTE band 1(2100), 2(1900), 3(1800), 4(1700/2100), 5(850), 7(2600), 8(900), 12(700), 13(700), 17(700), 20(800), 25(1900), 26(850), 28(700), 29(700), 30(2300), 38(2600), 41(2500), 66(1700/2100) - USA
#
#
#
# LTE band 1(2100), 3(1800), 5(850), 7(2600), 28(700) - Brazil
#
#
#
# LTE band 1(2100), 2(1900), 3(1800), 5(850), 7(2600), 8(900), 18(800), 19(800), 26(850), 28(700), 38(2600), 40(2300), 41(2500) - India
#
#
# Speed
# HSPA 42.2/5.76 Mbps, LTE Cat4 150/50 Mbps or LTE-A (2CA) Cat6 300/50 Mbps
#
#
#
# GPRS
# Yes
#
#
# EDGE
# Yes
# Launch
# Announced
# 2018, April
#
#
# Status
# Available. Released 2018, April
# Body
# Dimensions
# 153.8 x 72.3 x 8.3 mm (6.06 x 2.85 x 0.33 in)
#
# Weight
# 167 g (5.89 oz)
#
#
# Build
# Front/back glass, aluminum frame
#
#
# SIM
# Single SIM (Nano-SIM) or Dual SIM (Nano-SIM, dual stand-by)
#
#  - Splash resistant
# Display
# Type
# IPS LCD capacitive touchscreen, 16M colors
#
#
# Size
# 5.7 inches, 83.8 cm2 (~75.4% screen-to-body ratio)
#
#
# Resolution
# 1080 x 2160 pixels, 18:9 ratio (~424 ppi density)
#
#
# Multitouch
# Yes
#
#
# Protection
# Corning Gorilla Glass 3
# Platform
# OS
# Android 8.0 (Oreo)
#
# Chipset
# Qualcomm SDM450 Snapdragon 450
#
# CPU
# Octa-core 1.8 GHz Cortex-A53
#
# GPU
# Adreno 506
# Memory
# Card slot
#
#
# microSD, up to 256 GB
#
#
#
#
# Internal
# 64 GB, 4 GB RAM or 32 GB, 3 GB RAM
# Main Camera
# 		Dual
# 	12 MP, f/1.8, 1.4µm, PDAF
# 5 MP, f/2.2, depth sensor
#
#
# 	Features
# 	Dual-LED dual-tone flash, panorama, auto-HDR
#
#
# 	Video
# 	1080p@60/30fps
# Selfie camera
# 		Single
# 	8 MP or 16 MP, f/2.2
#
#
# 	Features
# 	LED flash
#
#
# 	Video
# 	1080p@30fps
# Sound
# Alert types
# Vibration; MP3, WAV ringtones
#
#
#
# Loudspeaker
# Yes
#
#
#
# 3.5mm jack
# Yes
#
#
#
#  - Active noise cancellation with dedicated mic
# - Dolby Audio
# Comms
# WLAN
# Wi-Fi 802.11 a/b/g/n, dual-band, WiFi Direct, hotspot
#
#
# Bluetooth
# 4.2, A2DP, LE, EDR
#
#
# GPS
# Yes, with A-GPS, GLONASS, BDS
#
#
# NFC
# Yes (Europe model)
#
#
#
#
# Radio
# FM radio
#
#
#
# USB
# 2.0, Type-C 1.0 reversible connector

# %%
print(soup.body.find_all('h1',{'data-spec':'modelname'})[0].text.strip())
print(soup.body.find_all('img')[1]['src'])
print(soup.body.find_all('span',{'data-spec':'released-hl'})[0].text.strip())
print(soup.body.find_all('span',{'data-spec':'body-hl'})[0].text.strip())
print(soup.body.find_all('span',{'data-spec':'os-hl'})[0].text.strip())
print(soup.body.find_all('span',{'data-spec':'storage-hl'})[0].text.strip())
print(soup.body.find_all('strong',{'class':'accent'})[4].text.strip())
print(soup.body.find_all('span',{'data-spec':'displaysize-hl'})[0].text.strip())
print(soup.body.find_all('strong',{'class':'accent'})[3].text.strip())
print(soup.body.find_all('strong',{'class':'accent'})[5].text.strip())
print(soup.body.find_all('div',{'data-spec':'battype-hl'})[0].text.strip())
print(soup.body.find_all('div',{'data-spec':'chipset-hl'})[0].text.strip())
print(soup.body.find_all('div',{'data-spec':'displayres-hl'})[0].text.strip())
print(soup.body.find_all('div',{'data-spec':'videopixels-hl'})[0].text.strip())
print(soup.body.find_all('a',{'class':'specs-fans'})[0].text.splitlines()[1].strip())
print(soup.body.find_all('li',{'class':'light pattern help help-popularity'})[0].text.splitlines()[2].strip())
print(soup.body.find_all('li',{'class':'light pattern help help-popularity'})[0].text.splitlines()[3].strip())
# Out:
# Motorola Moto G6
# https://cdn2.gsmarena.com/vv/bigpic/motorola-moto-g6-r1.jpg
# Released 2018, April
# 167g, 8.3mm thickness
# Android 8.0
# 64GB storage, microSD card slot
# 4GB RAM
# 5.7"
# 12MP
# 3000mAh
# Li-Ion
# Snapdragon 450
# 1080x2160 pixels
# 1080p
# 59
# 8.4%
# 1,069,852 hits

# %%
modelname=[]
img=[]
release=[]
body=[]
os=[]
storage=[]
display=[]
battery=[]
battery_type=[]
chipset=[]
displayres=[]
videopixels=[]
likes=[]
popularity=[]
User_hits=[]
for j in range(6,9280):
        try:
            ua = UserAgent()
            #print(ua.chrome)
            header = {'User-Agent':str(ua.chrome)}
            #print(header)
            url = 'https://www.gsmarena.com/acer_dx650-'+str(j)+'.php'
            source = requests.get(url, headers=header)
            soup = bs.BeautifulSoup(source.content,'html5lib')
            container=soup.body.find_all('table')
            #length_container=len(container)
            #print(length_container)
            modelname.append(soup.body.find_all('h1',{'data-spec':'modelname'})[0].text.strip())
            img.append(soup.body.find_all('img')[1]['src'])
            release.append(soup.body.find_all('span',{'data-spec':'released-hl'})[0].text.strip())
            body.append(soup.body.find_all('span',{'data-spec':'body-hl'})[0].text.strip())
            os.append(soup.body.find_all('span',{'data-spec':'os-hl'})[0].text.strip())
            storage.append(soup.body.find_all('span',{'data-spec':'storage-hl'})[0].text.strip())
            display.append(soup.body.find_all('span',{'data-spec':'displaysize-hl'})[0].text.strip())
            #camera.append(soup.body.find_all('span',{'data-spec':'camerapixels-hl'})[0].text.strip())
            battery.append(soup.body.find_all('span',{'data-spec':'batsize-hl'})[0].text.strip())
            battery_type.append(soup.body.find_all('div',{'data-spec':'battype-hl'})[0].text.strip())
            chipset.append(soup.body.find_all('div',{'data-spec':'chipset-hl'})[0].text.strip())
            displayres.append(soup.body.find_all('div',{'data-spec':'displayres-hl'})[0].text.strip())
            videopixels.append(soup.body.find_all('div',{'data-spec':'videopixels-hl'})[0].text.strip())
            likes.append(soup.body.find_all('a',{'class':'specs-fans'})[0].text.splitlines()[1].strip())
            popularity.append(soup.body.find_all('li',{'class':'light pattern help help-popularity'})[0].text.splitlines()[2].strip())
            User_hits.append(soup.body.find_all('li',{'class':'light pattern help help-popularity'})[0].text.splitlines()[3].strip())
        except Exception:
              pass

# %%
GSMArena_MobileData=pd.DataFrame()
GSMArena_MobileData['modelname']=pd.Series(modelname)
GSMArena_MobileData['img']=pd.Series(img)
GSMArena_MobileData['release']=pd.Series(release)
GSMArena_MobileData['body']=pd.Series(body)
GSMArena_MobileData['os']=pd.Series(os)
GSMArena_MobileData['storage']=pd.Series(storage)
GSMArena_MobileData['display']=pd.Series(display)
#GSMArena_MobileData['camerapixels-hl']=pd.Series()
GSMArena_MobileData['battery']=pd.Series(battery)
GSMArena_MobileData['battery_type']=pd.Series(battery_type)
GSMArena_MobileData['chipset']=pd.Series(chipset)
GSMArena_MobileData['displayres']=pd.Series(displayres)
GSMArena_MobileData['likes']=pd.Series(likes)
GSMArena_MobileData['videopixels']=pd.Series(videopixels)
GSMArena_MobileData['popularity']=pd.Series(popularity)
GSMArena_MobileData['User_hits']=pd.Series(User_hits)

# %%
#Data Frame
GSMArena_MobileData
# Out:
#                                modelname  \
# 0                             Nokia 3210
# 1                             Nokia 5110
# 2                             Nokia 6110
# 3                             Nokia 6130
# 4                             Nokia 6150
# 5                             Nokia 8110
# 6                             Nokia 6210
# 7                             Nokia 6250
# 8                             Nokia 7110
# 9                Nokia 9000 Communicator
# 10              Nokia 9110i Communicator
# 11                            Nokia 8210
# 12                            Nokia 8810
# 13                            Nokia 8850
# 14                            Nokia 8890
# 15                            Nokia 3110
# 16                            Nokia 2110
# 17                    alcatel OT Club db
# 18                    alcatel OT Easy db
# 19                     alcatel OT Max db
# 20                    alcatel OT View db
# 21                  alcatel OT View db @
# 22                     alcatel OT Pocket
# 23                        alcatel OT COM
# 24                        alcatel OT Pro
# 25                    alcatel OT Easy HF
# 26                       alcatel OT Easy
# 27                       alcatel OT Club
# 28                     alcatel OT Club +
# 29                        alcatel OT Max
# ...                                  ...
# 5326            Celkon A119 Signature HD
# 5327              Samsung Galaxy S4 CDMA
# 5328          LG Optimus L3 II Dual E435
# 5329                     LG Lucid2 VS870
# 5330     Samsung Galaxy Pocket Neo S5310
# 5331            Samsung Galaxy Win I8550
# 5332                        Icemobile G7
# 5333  Samsung Galaxy Trend II Duos S7572
# 5334                           HTC First
# 5335       Samsung Galaxy Mega 5.8 I9150
# 5336                        Xiaomi Mi 2S
# 5337       Samsung Galaxy Mega 6.3 I9200
# 5338              Acer Iconia Tab A1-810
# 5339              Gigabyte GSmart Rio R1
# 5340             Gigabyte GSmart Maya M1
# 5341                       ZTE Geek V975
# 5342                   Yezz Classic CC10
# 5343                      Yezz Andy A3.5
# 5344                        Yezz Andy A4
# 5345                      Yezz Andy A4.5
# 5346                       verykool s732
# 5347                        BLU Tattoo S
# 5348                            BLU Diva
# 5349                          BLU Diva X
# 5350                      BLU Dash Music
# 5351                     Plum Caliber II
# 5352                        Plum Panther
# 5353                           Plum Glow
# 5354                        Plum Trigger
# 5355                           Plum Z710
#
#                                                     img  \
# 0       https://cdn2.gsmarena.com/vv/bigpic/no3210b.gif
# 1       https://cdn2.gsmarena.com/vv/bigpic/no5110b.gif
# 2       https://cdn2.gsmarena.com/vv/bigpic/no6110b.gif
# 3       https://cdn2.gsmarena.com/vv/bigpic/no6130b.gif
# 4       https://cdn2.gsmarena.com/vv/bigpic/no6150b.gif
# 5       https://cdn2.gsmarena.com/vv/bigpic/no8110b.gif
# 6       https://cdn2.gsmarena.com/vv/bigpic/no6210b.gif
# 7       https://cdn2.gsmarena.com/vv/bigpic/no6250b.gif
# 8       https://cdn2.gsmarena.com/vv/bigpic/no7110b.gif
# 9       https://cdn2.gsmarena.com/vv/bigpic/no9000b.gif
# 10     https://cdn2.gsmarena.com/vv/bigpic/no9110ib.gif
# 11      https://cdn2.gsmarena.com/vv/bigpic/no8210t.gif
# 12      https://cdn2.gsmarena.com/vv/bigpic/no8810t.gif
# 13      https://cdn2.gsmarena.com/vv/bigpic/no8850t.gif
# 14      https://cdn2.gsmarena.com/vv/bigpic/no8890t.gif
# 15      https://cdn2.gsmarena.com/vv/bigpic/no3110b.gif
# 16      https://cdn2.gsmarena.com/vv/bigpic/no2110b.gif
# 17     https://cdn2.gsmarena.com/vv/bigpic/alclub2b.gif
# 18     https://cdn2.gsmarena.com/vv/bigpic/aleasy2b.gif
# 19      https://cdn2.gsmarena.com/vv/bigpic/almax2b.gif
# 20     https://cdn2.gsmarena.com/vv/bigpic/alview2b.gif
# 21     https://cdn2.gsmarena.com/vv/bigpic/alview3b.gif
# 22      https://cdn2.gsmarena.com/vv/bigpic/alpockb.gif
# 23       https://cdn2.gsmarena.com/vv/bigpic/alcomb.gif
# 24       https://cdn2.gsmarena.com/vv/bigpic/alprob.gif
# 25      https://cdn2.gsmarena.com/vv/bigpic/aleasyb.gif
# 26     https://cdn2.gsmarena.com/vv/bigpic/aleasy1b.gif
# 27      https://cdn2.gsmarena.com/vv/bigpic/alclubb.gif
# 28     https://cdn2.gsmarena.com/vv/bigpic/alclubpb.gif
# 29       https://cdn2.gsmarena.com/vv/bigpic/almaxb.gif
# ...                                                 ...
# 5326  https://cdn2.gsmarena.com/vv/bigpic/celkon-a11...
# 5327  https://cdn2.gsmarena.com/vv/bigpic/samsung-ga...
# 5328  https://cdn2.gsmarena.com/vv/bigpic/lg-optimus...
# 5329  https://cdn2.gsmarena.com/vv/bigpic/lg-lucid2-...
# 5330  https://cdn2.gsmarena.com/vv/bigpic/samsung-ga...
# 5331  https://cdn2.gsmarena.com/vv/bigpic/samsung-ga...
# 5332  https://cdn2.gsmarena.com/vv/bigpic/icemobile-...
# 5333  https://cdn2.gsmarena.com/vv/bigpic/samsung-ga...
# 5334  https://cdn2.gsmarena.com/vv/bigpic/htc-first.jpg
# 5335  https://cdn2.gsmarena.com/vv/bigpic/samsung-ga...
# 5336  https://cdn2.gsmarena.com/vv/bigpic/xiaomi-mi2...
# 5337  https://cdn2.gsmarena.com/vv/bigpic/samsung-ga...
# 5338  https://cdn2.gsmarena.com/vv/bigpic/acer-iconi...
# 5339  https://cdn2.gsmarena.com/vv/bigpic/Gigabyte-G...
# 5340  https://cdn2.gsmarena.com/vv/bigpic/Gigabyte-G...
# 5341   https://cdn2.gsmarena.com/vv/bigpic/zte-geek.jpg
# 5342  https://cdn2.gsmarena.com/vv/bigpic/yezz-class...
# 5343  https://cdn2.gsmarena.com/vv/bigpic/yezz-andy-...
# 5344  https://cdn2.gsmarena.com/vv/bigpic/yezz-andy-...
# 5345  https://cdn2.gsmarena.com/vv/bigpic/yezz-andy-...
# 5346  https://cdn2.gsmarena.com/vv/bigpic/verykool-s...
# 5347  https://cdn2.gsmarena.com/vv/bigpic/blu-tattoo...
# 5348   https://cdn2.gsmarena.com/vv/bigpic/blu-diva.jpg
# 5349  https://cdn2.gsmarena.com/vv/bigpic/blu-diva-x...
# 5350  https://cdn2.gsmarena.com/vv/bigpic/blu-dash-m...
# 5351  https://cdn2.gsmarena.com/vv/bigpic/plum-calib...
# 5352  https://cdn2.gsmarena.com/vv/bigpic/plum-panth...
# 5353  https://cdn2.gsmarena.com/vv/bigpic/plum-glow.jpg
# 5354  https://cdn2.gsmarena.com/vv/bigpic/plum-trigg...
# 5355  https://cdn2.gsmarena.com/vv/bigpic/plum-z710.jpg
#
#                       release                                    body  \
# 0               Released 1999                  151g, 22.5mm thickness
# 1               Released 1998                    170g, 31mm thickness
# 2               Released 1998                    137g, 28mm thickness
# 3               Released 1998                    152g, 25mm thickness
# 4               Released 1998                    141g, 28mm thickness
# 5               Released 1996                    152g, 25mm thickness
# 6               Released 2000                  114g, 18.8mm thickness
# 7               Released 2000                    167g, 27mm thickness
# 8                    Released                    141g, 24mm thickness
# 9               Released 1998                    397g, 38mm thickness
# 10              Released 1999                    253g, 27mm thickness
# 11              Released 1999                   79g, 17.4mm thickness
# 12              Released 1998                    118g, 18mm thickness
# 13              Released 1999                     91g, 17mm thickness
# 14              Released 2000                     91g, 18mm thickness
# 15              Released 1997  146g with slim battery, 21mm thickness
# 16              Released 1995                    236g, 25mm thickness
# 17              Released 2000                    150g, 25mm thickness
# 18              Released 2000                    150g, 25mm thickness
# 19              Released 2000                    150g, 25mm thickness
# 20              Released 2000                    150g, 25mm thickness
# 21              Released 2000                    150g, 25mm thickness
# 22              Released 1999                    125g, 19mm thickness
# 23              Released 1998                    230g, 24mm thickness
# 24              Released 1998                    145g, 15mm thickness
# 25              Released 1998                    160g, 25mm thickness
# 26              Released 1998                    160g, 25mm thickness
# 27              Released 1998                    160g, 28mm thickness
# 28              Released 1998                    160g, 28mm thickness
# 29              Released 1998                    160g, 25mm thickness
# ...                       ...                                     ...
# 5326     Released 2013, March                   177g, 9.3mm thickness
# 5327       Released 2013, May                 130.1g, 7.9mm thickness
# 5328     Released 2013, April                  110g, 11.9mm thickness
# 5329     Released 2013, April                   129g, 9.8mm thickness
# 5330      Released 2013, June                100.5g, 11.8mm thickness
# 5331       Released 2013, May                 143.9g, 9.7mm thickness
# 5332     Released 2013, April                   450g, 9.8mm thickness
# 5333       Released 2013, May                128.5g, 11.1mm thickness
# 5334     Released 2013, April                 123.9g, 8.9mm thickness
# 5335       Released 2013, May                     182g, 9mm thickness
# 5336     Released 2013, April                  145g, 10.2mm thickness
# 5337      Released 2013, June                     199g, 8mm thickness
# 5338       Released 2013, May                  410g, 11.1mm thickness
# 5339     Released 2013, April                130.5g, 10.5mm thickness
# 5340     Released 2013, April                 150.5g, 9.7mm thickness
# 5341    Released 2013, August                   148g, 9.5mm thickness
# 5342     Released 2012, April   55g without battery, 14.4mm thickness
# 5343  Released 2012, November   82g without battery, 11.9mm thickness
# 5344     Released 2013, April   104g without battery, 9.8mm thickness
# 5345       Released 2013, May   102g without battery, 8.6mm thickness
# 5346            Released 2013                  120g, 12.8mm thickness
# 5347     Released 2013, March                    69g, 8.3mm thickness
# 5348     Released 2013, April                     90g, 14mm thickness
# 5349       Released 2013, May                   95g, 13.5mm thickness
# 5350       Released 2013, May                  120g, 13.4mm thickness
# 5351     Released 2013, April                  125g, 13.5mm thickness
# 5352     Released 2013, April   47g without battery, 21.5mm thickness
# 5353     Released 2013, April                  105g, 12.9mm thickness
# 5354     Released 2013, April                  103g, 11.6mm thickness
# 5355     Released 2013, April
#
#                               os                                   storage  \
# 0                  Feature phone                              No card slot
# 1                  Feature phone                              No card slot
# 2                  Feature phone                              No card slot
# 3                  Feature phone                              No card slot
# 4                  Feature phone                              No card slot
# 5                  Feature phone                              No card slot
# 6                  Feature phone                              No card slot
# 7                  Feature phone                              No card slot
# 8                  Feature phone                              No card slot
# 9                  Feature phone                 8MB storage, no card slot
# 10                 Feature phone                8MB storage, MMC card slot
# 11                 Feature phone                              No card slot
# 12                 Feature phone                              No card slot
# 13                 Feature phone                              No card slot
# 14                 Feature phone                              No card slot
# 15                 Feature phone                              No card slot
# 16                 Feature phone                              No card slot
# 17                 Feature phone                              No card slot
# 18                 Feature phone                              No card slot
# 19                 Feature phone                              No card slot
# 20                 Feature phone                              No card slot
# 21                 Feature phone                              No card slot
# 22                 Feature phone                              No card slot
# 23                 Feature phone              512 KB storage, no card slot
# 24                 Feature phone                              No card slot
# 25                 Feature phone                              No card slot
# 26                 Feature phone                              No card slot
# 27                 Feature phone                              No card slot
# 28                 Feature phone                              No card slot
# 29                 Feature phone                              No card slot
# ...                          ...                                       ...
# 5326                 Android 4.1            4GB storage, microSD card slot
# 5327  Android 4.2.2, up to 5.0.1           16GB storage, microSD card slot
# 5328               Android 4.1.2            4GB storage, microSD card slot
# 5329               Android 4.1.2            8GB storage, microSD card slot
# 5330               Android 4.1.2            4GB storage, microSD card slot
# 5331               Android 4.1.2            8GB storage, microSD card slot
# 5332                  Android OS                         microSD card slot
# 5333                 Android 4.1                         microSD card slot
# 5334                 Android 4.1                16GB storage, no card slot
# 5335               Android 4.2.2            8GB storage, microSD card slot
# 5336    Android 4.1, up to 4.4.4             16/32GB storage, no card slot
# 5337  Android 4.2.2, up to 4.4.2         8/16GB storage, microSD card slot
# 5338               Android 4.2.2         8/16GB storage, microSD card slot
# 5339                 Android 4.0            4GB storage, microSD card slot
# 5340                 Android 4.1            4GB storage, microSD card slot
# 5341               Android 4.2.2         8/16GB storage, microSD card slot
# 5342               Feature phone  64 Mb + 64 Mb storage, microSD card slot
# 5343                 Android 4.0                         microSD card slot
# 5344                 Android 4.1            4GB storage, microSD card slot
# 5345                 Android 4.2            4GB storage, microSD card slot
# 5346               Android 2.3.7                         microSD card slot
# 5347               Feature phone       64MB ROM storage, microSD card slot
# 5348               Feature phone       32MB ROM storage, microSD card slot
# 5349               Feature phone       64MB ROM storage, microSD card slot
# 5350                 Android 2.3          512MB storage, microSD card slot
# 5351               Feature phone            1GB storage, microSD card slot
# 5352               Feature phone       64MB ROM storage, microSD card slot
# 5353               Android 2.3.5          512MB storage, microSD card slot
# 5354                 Android 4.0          512MB storage, microSD card slot
# 5355               Android 4.1.2           16GB storage, microSD card slot
#
#      display battery battery_type chipset                displayres likes  \
# 0                600        Li-Po                           5 lines    89
# 1                600        Li-Po                           5 lines    64
# 2                600        Li-Po                           5 lines    31
# 3                600        Li-Po                           5 lines    42
# 4                400       Li-Ion                   4x13 characters    56
# 5               1050       Li-Ion             96x60 pixels, 6 lines    61
# 6               1200       Li-Ion             96x60 pixels, 6 lines    28
# 7                600        Li-Po             96x65 pixels, 6 lines    47
# 8               1100       Li-Ion                    640x200 pixels    50
# 9                650       Li-Ion                           5 lines    71
# 10      4.5"     600         NiMH                           5 lines    40
# 11               830       Li-Ion                           5 lines    39
# 12               830       Li-Ion                           5 lines    36
# 13               400       Li-Ion                   4x13 characters    35
# 14               550         NiMH                   4x13 characters    63
# 15               650         NiMH                           3 lines    14
# 16               650         NiMH                           3 lines    14
# 17               650         NiMH                           3 lines    11
# 18               650         NiMH          96x64 pixels, 5x15 chars    13
# 19               650         NiMH          96x64 pixels, 5x15 chars    11
# 20               600       Li-Ion          96x64 pixels, 5x15 chars    11
# 21               880         NiMH                    160x239 pixels    13
# 22               600         NiMH                        4x16 chars     8
# 23               580         NiMH                        2x12 chars    10
# 24               580         NiMH                        2x12 chars    19
# 25               580         NiMH                        2x12 chars    12
# 26               580         NiMH                        2x12 chars    10
# 27               580         NiMH                        2x12 chars    11
# 28               580         NiMH                        5x15 chars    11
# 29               600         NiMH                        4x16 chars     8
# ...      ...     ...          ...     ...                       ...   ...
# 5326    5.0"     NaN          NaN     NaN                       NaN   NaN
# 5327    5.0"     NaN          NaN     NaN                       NaN   NaN
# 5328    3.2"     NaN          NaN     NaN                       NaN   NaN
# 5329    4.3"     NaN          NaN     NaN                       NaN   NaN
# 5330    3.0"     NaN          NaN     NaN                       NaN   NaN
# 5331    4.7"     NaN          NaN     NaN                       NaN   NaN
# 5332    7.0"     NaN          NaN     NaN                       NaN   NaN
# 5333    4.0"     NaN          NaN     NaN                       NaN   NaN
# 5334    4.3"     NaN          NaN     NaN                       NaN   NaN
# 5335    5.8"     NaN          NaN     NaN                       NaN   NaN
# 5336    4.3"     NaN          NaN     NaN                       NaN   NaN
# 5337    6.3"     NaN          NaN     NaN                       NaN   NaN
# 5338    7.9"     NaN          NaN     NaN                       NaN   NaN
# 5339    4.0"     NaN          NaN     NaN                       NaN   NaN
# 5340    4.5"     NaN          NaN     NaN                       NaN   NaN
# 5341    5.0"     NaN          NaN     NaN                       NaN   NaN
# 5342    1.8"     NaN          NaN     NaN                       NaN   NaN
# 5343    3.5"     NaN          NaN     NaN                       NaN   NaN
# 5344    4.0"     NaN          NaN     NaN                       NaN   NaN
# 5345    4.5"     NaN          NaN     NaN                       NaN   NaN
# 5346    3.5"     NaN          NaN     NaN                       NaN   NaN
# 5347    2.0"     NaN          NaN     NaN                       NaN   NaN
# 5348    2.4"     NaN          NaN     NaN                       NaN   NaN
# 5349    2.8"     NaN          NaN     NaN                       NaN   NaN
# 5350    3.5"     NaN          NaN     NaN                       NaN   NaN
# 5351    2.4"     NaN          NaN     NaN                       NaN   NaN
# 5352   1.44"     NaN          NaN     NaN                       NaN   NaN
# 5353    3.5"     NaN          NaN     NaN                       NaN   NaN
# 5354    3.5"     NaN          NaN     NaN                       NaN   NaN
# 5355    7.0"     NaN          NaN     NaN                       NaN   NaN
#
#             videopixels popularity     User_hits
# 0     No video recorder       0.1%  813,562 hits
# 1     No video recorder       0.1%  751,101 hits
# 2     No video recorder        N/A  340,726 hits
# 3     No video recorder        N/A  347,739 hits
# 4     No video recorder       0.1%  499,932 hits
# 5     No video recorder        N/A  608,476 hits
# 6     No video recorder        N/A  275,153 hits
# 7     No video recorder        N/A  425,015 hits
# 8     No video recorder        N/A  400,501 hits
# 9     No video recorder       0.1%  669,821 hits
# 10    No video recorder       0.1%  432,743 hits
# 11    No video recorder        N/A  508,589 hits
# 12    No video recorder        N/A  382,287 hits
# 13    No video recorder        N/A  462,062 hits
# 14    No video recorder        N/A  781,038 hits
# 15    No video recorder        N/A   86,727 hits
# 16    No video recorder        N/A  117,774 hits
# 17    No video recorder        N/A   88,223 hits
# 18    No video recorder        N/A   83,174 hits
# 19    No video recorder        N/A   76,457 hits
# 20    No video recorder        N/A   83,284 hits
# 21    No video recorder        N/A  114,892 hits
# 22    No video recorder        N/A   63,476 hits
# 23    No video recorder        N/A   86,166 hits
# 24    No video recorder        N/A  160,307 hits
# 25    No video recorder        N/A   79,763 hits
# 26    No video recorder        N/A   71,838 hits
# 27    No video recorder        N/A   81,044 hits
# 28    No video recorder        N/A   74,847 hits
# 29    No video recorder        N/A   70,487 hits
# ...                 ...        ...           ...
# 5326                NaN        NaN           NaN
# 5327                NaN        NaN           NaN
# 5328                NaN        NaN           NaN
# 5329                NaN        NaN           NaN
# 5330                NaN        NaN           NaN
# 5331                NaN        NaN           NaN
# 5332                NaN        NaN           NaN
# 5333                NaN        NaN           NaN
# 5334                NaN        NaN           NaN
# 5335                NaN        NaN           NaN
# 5336                NaN        NaN           NaN
# 5337                NaN        NaN           NaN
# 5338                NaN        NaN           NaN
# 5339                NaN        NaN           NaN
# 5340                NaN        NaN           NaN
# 5341                NaN        NaN           NaN
# 5342                NaN        NaN           NaN
# 5343                NaN        NaN           NaN
# 5344                NaN        NaN           NaN
# 5345                NaN        NaN           NaN
# 5346                NaN        NaN           NaN
# 5347                NaN        NaN           NaN
# 5348                NaN        NaN           NaN
# 5349                NaN        NaN           NaN
# 5350                NaN        NaN           NaN
# 5351                NaN        NaN           NaN
# 5352                NaN        NaN           NaN
# 5353                NaN        NaN           NaN
# 5354                NaN        NaN           NaN
# 5355                NaN        NaN           NaN
#
# [5356 rows x 15 columns]

# %%
GSMArena_MobileData.to_csv('./GSMArena_MobileData.csv', encoding='utf-8', index=False)
